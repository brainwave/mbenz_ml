# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np
from sklearn.base import BaseEstimator,TransformerMixin, ClassifierMixin
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import ElasticNetCV, LassoLarsCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import make_pipeline, make_union
from sklearn.utils import check_array
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection
from sklearn.decomposition import PCA, FastICA
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import r2_score



class StackingEstimator(BaseEstimator, TransformerMixin):
    
    def __init__(self, estimator):
        self.estimator = estimator

    def fit(self, X, y=None, **fit_params):
        self.estimator.fit(X, y, **fit_params)
        return self
    def transform(self, X):
        X = check_array(X)
        X_transformed = np.copy(X)
        # add class probabilities as a synthetic feature
        if issubclass(self.estimator.__class__, ClassifierMixin) and hasattr(self.estimator, 'predict_proba'):
            X_transformed = np.hstack((self.estimator.predict_proba(X), X))

        # add class prodiction as a synthetic feature
        X_transformed = np.hstack((np.reshape(self.estimator.predict(X), (-1, 1)), X_transformed))

        return X_transformed


train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

for c in train.columns:
    if train[c].dtype == 'object':
        lbl = LabelEncoder()
        lbl.fit(list(train[c].values) + list(test[c].values))
        train[c] = lbl.transform(list(train[c].values))
        test[c] = lbl.transform(list(test[c].values))

n_comp = 12

# %%
# truncated Singular value decomposition
tsvd = TruncatedSVD(n_components=n_comp, random_state=420)
tsvd_results_train = tsvd.fit_transform(train.drop(["y"], axis=1))
tsvd_results_test = tsvd.transform(test)

# Principle Component Analysis
pca = PCA(n_components=n_comp, random_state=420)
pca2_results_train = pca.fit_transform(train.drop(["y"], axis=1))
pca2_results_test = pca.transform(test)

# Independent Component Analysis
ica = FastICA(n_components=n_comp, random_state=420)
ica2_results_train = ica.fit_transform(train.drop(["y"], axis=1))
ica2_results_test = ica.transform(test)

# Gaussian Random Projection
grp = GaussianRandomProjection(n_components=n_comp, eps=0.1, random_state=420)
grp_results_train = grp.fit_transform(train.drop(["y"], axis=1))
grp_results_test = grp.transform(test)

# Sparse Random Projection
srp = SparseRandomProjection(n_components=n_comp, dense_output=True, random_state=420)
srp_results_train = srp.fit_transform(train.drop(["y"], axis=1))
srp_results_test = srp.transform(test)

#save columns list before adding the decomposition components

usable_columns = list(set(train.columns) - set(['y']))

# %%
# Append decomposition components to datasets
for i in range(1, n_comp + 1):
    train['pca_' + str(i)] = pca2_results_train[:, i - 1]
    test['pca_' + str(i)] = pca2_results_test[:, i - 1]

    train['ica_' + str(i)] = ica2_results_train[:, i - 1]
    test['ica_' + str(i)] = ica2_results_test[:, i - 1]

    train['tsvd_' + str(i)] = tsvd_results_train[:, i - 1]
    test['tsvd_' + str(i)] = tsvd_results_test[:, i - 1]

    train['grp_' + str(i)] = grp_results_train[:, i - 1]
    test['grp_' + str(i)] = grp_results_test[:, i - 1]

    train['srp_' + str(i)] = srp_results_train[:, i - 1]
    test['srp_' + str(i)] = srp_results_test[:, i - 1]

#usable_columns = list(set(train.columns) - set(['y']))

y_train = train['y'].values
y_mean = np.mean(y_train)
id_test = test['ID'].values
#finaltrainset and finaltestset are data to be used only the stacked model (does not contain PCA, SVD... arrays) 
finaltrainset = train[usable_columns].values
finaltestset = test[usable_columns].values

# %%
print('Total columns in training set: ',(train.shape[1] - finaltrainset.shape[1]))
print('Total columns in testing set:',(test.shape[1] - finaltestset.shape[1]) )
# Out:
# Final train Set Columns:  61

# %%
#Train the xgb model then predict the test data
xgb_params = {
    'n_trees': 520, 
    'eta': 0.0045,
    'max_depth': 4,
    'subsample': 0.93,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'base_score': y_mean, # base prediction = mean(target)
    'silent': 1
}
# NOTE: Make sure that the class is labeled 'class' in the data file

dtrain = xgb.DMatrix(train.drop('y', axis=1), y_train)
dtest = xgb.DMatrix(test)

num_boost_rounds = 1250
# train model
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=num_boost_rounds)
y_pred = model.predict(dtest)

'''Train the stacked models then predict the test data'''

stacked_pipeline = make_pipeline(
    StackingEstimator(estimator=LassoLarsCV(normalize=True)),
    StackingEstimator(estimator=GradientBoostingRegressor(learning_rate=0.001, loss="huber", max_depth=3, max_features=0.55, min_samples_leaf=18, min_samples_split=14, subsample=0.7)),
    LassoLarsCV()

)
# Out:
# [12:27:19] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1637426272325/work/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# [12:27:19] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1637426272325/work/src/learner.cc:576:
# Parameters: { "n_trees", "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
stacked_pipeline.fit(finaltrainset, y_train)
results = stacked_pipeline.predict(finaltestset)

'''R2 Score on the entire Train data when averaging'''

print('R2 score on train data:')
print(r2_score(y_train,stacked_pipeline.predict(finaltrainset)*0.2855 + model.predict(dtrain)*0.7145))

'''Average the preditionon test data  of both models then save it on a csv file'''

sub = pd.DataFrame()
sub['ID'] = id_test
sub['y'] = y_pred*0.75 + results*0.25
sub.to_csv('stacked-averaged-models.csv', index=False)

# Any results you write to the current directory are saved as output.
# Out:
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.294e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.992e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.992e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.601e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.444e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.444e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.293e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.293e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=1.023e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=1.037e-02, previous alpha=1.005e-02, with an active set of 23 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.098e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.098e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.326e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=8.252e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=5.489e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=5.489e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=5.489e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=4.762e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=4.603e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 7.525e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.334e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=4.055e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=4.006e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=3.087e-03, with an active set of 49 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=2.870e-03, with an active set of 54 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=2.769e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=2.738e-03, with an active set of 56 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=2.610e-03, with an active set of 62 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=2.610e-03, with an active set of 62 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=2.610e-03, with an active set of 62 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=2.607e-03, with an active set of 62 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=2.257e-03, with an active set of 68 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 81 iterations, i.e. alpha=2.003e-03, with an active set of 79 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 83 iterations, i.e. alpha=1.991e-03, with an active set of 81 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 83 iterations, i.e. alpha=1.987e-03, with an active set of 81 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 85 iterations, alpha=1.978e-03, previous alpha=1.961e-03, with an active set of 82 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.231e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.892e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.892e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=2.566e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.977e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.798e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.395e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.395e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.323e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.275e-02, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 18 iterations, alpha=1.275e-02, previous alpha=1.273e-02, with an active set of 17 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.335e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.249e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.249e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.249e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.096e-02, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.096e-02, with an active set of 18 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=7.841e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=7.841e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=7.399e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=6.203e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=6.203e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=6.203e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=5.951e-03, previous alpha=5.929e-03, with an active set of 29 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.166e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.013e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=7.247e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.646e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.254e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.254e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.254e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=5.056e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=4.788e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=4.138e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=4.128e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 43 iterations, i.e. alpha=3.938e-03, with an active set of 39 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.762e-03, with an active set of 41 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 47 iterations, i.e. alpha=3.605e-03, with an active set of 43 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 47 iterations, i.e. alpha=3.605e-03, with an active set of 43 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=3.430e-03, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=3.090e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=3.071e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 60 iterations, alpha=3.129e-03, previous alpha=3.053e-03, with an active set of 55 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.030e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.030e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.030e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.462e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.813e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.813e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.813e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.813e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=9.146e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 21 iterations, alpha=9.295e-03, previous alpha=9.130e-03, with an active set of 20 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_base.py:138: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsCV())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   FutureWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.112e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=4.178e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=3.133e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=2.853e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=2.798e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.695e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.695e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.695e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.640e-03, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=2.354e-03, with an active set of 50 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=2.349e-03, with an active set of 52 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=2.292e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 66 iterations, i.e. alpha=2.047e-03, with an active set of 66 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 66 iterations, i.e. alpha=2.014e-03, with an active set of 66 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 71 iterations, alpha=1.948e-03, previous alpha=1.855e-03, with an active set of 70 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=5.222e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=4.699e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.064e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=2.676e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.673e-03, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=2.587e-03, with an active set of 41 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=2.482e-03, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 49 iterations, i.e. alpha=2.392e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.927e-03, with an active set of 63 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=1.885e-03, with an active set of 68 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=1.885e-03, with an active set of 68 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=1.852e-03, with an active set of 70 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 78 iterations, i.e. alpha=1.759e-03, with an active set of 74 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 84 iterations, i.e. alpha=1.673e-03, with an active set of 80 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 84 iterations, i.e. alpha=1.673e-03, with an active set of 80 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 92 iterations, i.e. alpha=1.556e-03, with an active set of 86 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=1.482e-03, with an active set of 92 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 104 iterations, alpha=1.518e-03, previous alpha=1.429e-03, with an active set of 97 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.110e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.957e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.555e-03, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.555e-03, with an active set of 40 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.555e-03, with an active set of 40 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=2.364e-03, with an active set of 44 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=2.096e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 65 iterations, i.e. alpha=1.881e-03, with an active set of 63 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 66 iterations, i.e. alpha=1.873e-03, with an active set of 64 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.845e-03, with an active set of 66 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=1.799e-03, with an active set of 68 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 78 iterations, alpha=1.724e-03, previous alpha=1.695e-03, with an active set of 75 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.123e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=5.032e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.545e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.418e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=4.158e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=3.110e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.987e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.987e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=2.733e-03, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=2.422e-03, with an active set of 49 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 52 iterations, alpha=2.603e-03, previous alpha=2.379e-03, with an active set of 49 regressors.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.811e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.710e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=3.691e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=3.691e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=3.648e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:659: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=3.366e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning,
# /home/brainwave/miniconda3/envs/directml/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:687: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 36 iterations, alpha=3.114e-03, previous alpha=3.043e-03, with an active set of 33 regressors.
#   ConvergenceWarning,
# R2 score on train data:
# 0.6589339880475449
